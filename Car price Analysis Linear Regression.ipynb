# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt=pd.read_csv("CarPrice_Assignment.csv")

# %%
display(dt)
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
#EDA
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
dt.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
dt.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
dt['CarName'].value_counts()
# Out:
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: CarName, Length: 147, dtype: int64

# %%
dt['fueltype'].value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
sn.countplot(x=dt['fueltype'])
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='count'>

# %%
dt['aspiration'].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
sn.countplot(x=dt['aspiration'])
# Out:
# <AxesSubplot:xlabel='aspiration', ylabel='count'>

# %%
dt['enginetype'].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
sn.countplot(x=dt['enginetype'])
# Out:
# <AxesSubplot:xlabel='enginetype', ylabel='count'>

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc=OrdinalEncoder()
a=['CarName']
b=['fueltype']
c=['aspiration']
d=['doornumber']
e=['carbody']
r=['drivewheel']
s=['enginelocation']
v=['cylindernumber']
u=['enginetype']
w=['fuelsystem']
dt[a]=enc.fit_transform(dt[a])
dt[b]=enc.fit_transform(dt[b])
dt[c]=enc.fit_transform(dt[c])
dt[d]=enc.fit_transform(dt[d])
dt[e]=enc.fit_transform(dt[e])
dt[r]=enc.fit_transform(dt[r])
dt[s]=enc.fit_transform(dt[s])
dt[v]=enc.fit_transform(dt[v])
dt[u]=enc.fit_transform(dt[u])
dt[w]=enc.fit_transform(dt[w])

# %%
dt
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3      2.0       1.0         0.0         1.0      0.0
# 1         2          3      3.0       1.0         0.0         1.0      0.0
# 2         3          1      1.0       1.0         0.0         1.0      2.0
# 3         4          2      4.0       1.0         0.0         0.0      3.0
# 4         5          2      5.0       1.0         0.0         0.0      3.0
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1    139.0       1.0         0.0         0.0      3.0
# 201     202         -1    138.0       1.0         1.0         0.0      3.0
# 202     203         -1    140.0       1.0         0.0         0.0      3.0
# 203     204         -1    142.0       0.0         1.0         0.0      3.0
# 204     205         -1    143.0       1.0         1.0         0.0      3.0
#
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    float64
#  3   fueltype          205 non-null    float64
#  4   aspiration        205 non-null    float64
#  5   doornumber        205 non-null    float64
#  6   carbody           205 non-null    float64
#  7   drivewheel        205 non-null    float64
#  8   enginelocation    205 non-null    float64
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    float64
#  15  cylindernumber    205 non-null    float64
# ...

# %%
dt.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
dt=dt.astype({"CarName":'int',"fueltype":'int',"aspiration":'int',
    "doornumber":'int',"carbody":'int',"drivewheel":'int',"enginelocation":'int',"cylindernumber":'int',"enginetype":'int',"fuelsystem":'int',"price":'int'})

# %%
dt
# Out:
#      car_ID  symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0         1          3        2         1           0           1        0
# 1         2          3        3         1           0           1        0
# 2         3          1        1         1           0           1        2
# 3         4          2        4         1           0           0        3
# 4         5          2        5         1           0           0        3
# ..      ...        ...      ...       ...         ...         ...      ...
# 200     201         -1      139         1           0           0        3
# 201     202         -1      138         1           1           0        3
# 202     203         -1      140         1           0           0        3
# 203     204         -1      142         0           1           0        3
# 204     205         -1      143         1           1           0        3
#
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    int32
#  3   fueltype          205 non-null    int32
#  4   aspiration        205 non-null    int32
#  5   doornumber        205 non-null    int32
#  6   carbody           205 non-null    int32
#  7   drivewheel        205 non-null    int32
#  8   enginelocation    205 non-null    int32
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    int32
#  15  cylindernumber    205 non-null    int32
# ...

# %%
cor=dt.corr()
cor.style.background_gradient(cmap="winter")
# Out:
# <style type="text/css">
# #T_7c9b1_row0_col0, #T_7c9b1_row1_col1, #T_7c9b1_row2_col2, #T_7c9b1_row3_col3, #T_7c9b1_row4_col4, #T_7c9b1_row5_col5, #T_7c9b1_row6_col6, #T_7c9b1_row7_col7, #T_7c9b1_row8_col8, #T_7c9b1_row9_col9, #T_7c9b1_row10_col10, #T_7c9b1_row11_col11, #T_7c9b1_row12_col12, #T_7c9b1_row13_col13, #T_7c9b1_row14_col14, #T_7c9b1_row15_col15, #T_7c9b1_row16_col16, #T_7c9b1_row17_col17, #T_7c9b1_row18_col18, #T_7c9b1_row19_col19, #T_7c9b1_row20_col20, #T_7c9b1_row21_col21, #T_7c9b1_row22_col22, #T_7c9b1_row23_col23, #T_7c9b1_row24_col24, #T_7c9b1_row25_col25 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_7c9b1_row0_col1, #T_7c9b1_row5_col11 {
#   background-color: #0047dc;
#   color: #f1f1f1;
# }
# #T_7c9b1_row0_col2 {
#   background-color: #00f982;
#   color: #000000;
# }
# #T_7c9b1_row0_col3, #T_7c9b1_row17_col1, #T_7c9b1_row25_col12 {
#   background-color: #006ec8;
#   color: #f1f1f1;
# }
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scal=StandardScaler()
scal.fit(dt)
scaled=scal.transform(dt)
scaled
# Out:
# array([[-1.72362229,  1.74347043, -1.83822103, ..., -0.64655303,
#         -0.54605874,  0.02739218],
#        [-1.70672403,  1.74347043, -1.81377978, ..., -0.64655303,
#         -0.54605874,  0.40446229],
#        [-1.68982577,  0.133509  , -1.86266229, ..., -0.95301169,
#         -0.69162706,  0.40446229],
#        ...,
#        [ 1.68982577, -1.47645244,  1.53467254, ..., -1.10624102,
#         -1.12833203,  1.02998459],
#        [ 1.70672403, -1.47645244,  1.58355505, ...,  0.11959362,
#         -0.54605874,  1.15358328],
#        [ 1.72362229, -1.47645244,  1.60799631, ..., -0.95301169,
#         -0.83719538,  1.17303282]])

# %%
scaled=pd.DataFrame(scaled,columns=dt.columns)

# %%
scaled
# Out:
#        car_ID  symboling   CarName  fueltype  aspiration  doornumber  \
# 0   -1.723622   1.743470 -1.838221  0.328798   -0.469295    1.130388
# 1   -1.706724   1.743470 -1.813780  0.328798   -0.469295    1.130388
# 2   -1.689826   0.133509 -1.862662  0.328798   -0.469295    1.130388
# 3   -1.672928   0.938490 -1.789339  0.328798   -0.469295   -0.884652
# 4   -1.656029   0.938490 -1.764897  0.328798   -0.469295   -0.884652
# ..        ...        ...       ...       ...         ...         ...
# 200  1.656029  -1.476452  1.510231  0.328798   -0.469295   -0.884652
# 201  1.672928  -1.476452  1.485790  0.328798    2.130854   -0.884652
# 202  1.689826  -1.476452  1.534673  0.328798   -0.469295   -0.884652
# 203  1.706724  -1.476452  1.583555 -3.041381    2.130854   -0.884652
# 204  1.723622  -1.476452  1.607996  0.328798    2.130854   -0.884652
#
#       carbody  drivewheel  enginelocation  wheelbase  ...  enginesize  \
# ...

# %%
# Train-Test Split Process
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
x=scaled.iloc[:,0:25]
y=scaled["price"]

# %%
x_train
# Out:
#        car_ID  symboling   CarName  fueltype  aspiration  doornumber  \
# 1   -1.706724   1.743470 -1.813780  0.328798   -0.469295    1.130388
# 112  0.168983  -0.671472  0.263727 -3.041381    2.130854   -0.884652
# 162  1.013895  -0.671472  1.168054  0.328798   -0.469295   -0.884652
# 87  -0.253474   0.133509 -0.225098  0.328798    2.130854   -0.884652
# 99  -0.050695  -0.671472  0.092638  0.328798   -0.469295   -0.884652
# ..        ...        ...       ...       ...         ...         ...
# 140  0.642134   0.938490  0.728111  0.328798   -0.469295    1.130388
# 45  -0.963201  -0.671472 -0.762806  0.328798   -0.469295   -0.884652
# 173  1.199776  -1.476452  0.923641  0.328798   -0.469295   -0.884652
# 165  1.064590   0.133509  0.899200  0.328798   -0.469295    1.130388
# 37  -1.098387  -0.671472 -1.007218  0.328798   -0.469295    1.130388
#
#       carbody  drivewheel  enginelocation  wheelbase  ...  cylindernumber  \
# ...

# %%
# Model Building For Prediction
from sklearn.linear_model import LinearRegression

# %%
model2=LinearRegression()
model2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred2=model2.predict(x_test)
print(y_pred2)
# Out:
# [-1.03207293 -0.40583314 -0.74256805 -0.2187527   2.06624326  0.99512029
#  -0.81714418 -0.68581696 -1.05545751 -0.59888823 -0.47889136 -0.81162939
#   0.8258337   0.3419522  -0.55350968 -0.79992338 -0.56490812 -0.60091799
#  -0.29884992 -0.67174987 -0.65340702 -0.20558049 -0.36422374  1.06057694
#   0.9910208   0.0091652  -0.34410812 -0.96789791  0.81365178  0.09896285
#  -0.19972395  2.01325115 -0.89297832 -0.797865   -0.48927314 -0.29814715
#  -0.88749953 -0.44777715  0.05647681  2.02383975 -0.82687711]

# %%
# Checking R squared Value.
from sklearn.metrics import r2_score

# %%
# Claculating R Squared Value.
acc2=r2_score(y_test,y_pred2)
print("Accuracy is:",acc2*100)
# Out:
# Accuracy is: 84.1919269798965

# %%
# Co-Efficient Calculation
print(model2.coef_)
# Out:
# [ 0.13478626  0.01130266 -0.30502848 -0.32719884 -0.02697245 -0.04493155
#  -0.10568977  0.04898898  0.15006075  0.10610686  0.05520321  0.12212303
#   0.10277771 -0.01264011  0.02287896  0.04730705  0.43730782  0.02092754
#  -0.02035386 -0.10545643 -0.20894334  0.25718684  0.08399898  0.03103426
#   0.02019571]

# %%
# Intercept Calculation
print(model2.intercept_)
# Out:
# 0.005105604203883382

# %%
sns.regplot(data=scaled,x=y_test,y=y_pred2,color='red')
# Out:
# <AxesSubplot:xlabel='price'>
